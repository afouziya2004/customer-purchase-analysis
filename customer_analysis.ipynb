# %% [markdown]
# <a href="https://colab.research.google.com/github/afouziya2004/customer-purchase-analysis/blob/notebooks/customer_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from src.data_loader import load_online_retail_data
from src.data_cleaning import clean_data
from src.purchase_metrics import add_revenue

df = load_online_retail_data()
df = clean_data(df)
df = add_revenue(df)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1759487310.py in <cell line: 0>()
# ----> 1 from src.data_loader import load_online_retail_data
#       2 from src.data_cleaning import clean_data
#       3 from src.purchase_metrics import add_revenue
#       4
#       5 df = load_online_retail_data()
#
# ModuleNotFoundError: No module named 'src'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
